# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
# Out:
# /tmp/ipykernel_82680/487022753.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
pred_npy_1 =  np.load("./results/336_1_PatchTST_custom_ftMS_sl336_ll48_pl1_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/pred.npy") 
true_npy_1 =  np.load("./results/336_1_PatchTST_custom_ftMS_sl336_ll48_pl1_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/true.npy")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 pred_npy_1 =  np.load("./results/336_1_PatchTST_custom_ftMS_sl336_ll48_pl1_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/pred.npy")
#       2 true_npy_1 =  np.load("./results/336_1_PatchTST_custom_ftMS_sl336_ll48_pl1_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/true.npy")
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# ...

# %%
print(pred_npy_1.shape)
print(true_npy_1.shape)
# Out:
# (12480, 1)
# (12480, 1)

# %%
pred_npy_1 = pred_npy_1.reshape(-1, pred_npy_1.shape[-1])
true_npy_1 = true_npy_1.reshape(-1, true_npy_1.shape[-1])


# Create DataFrame
df_pred = pd.DataFrame(pred_npy_1)
df_true = pd.DataFrame(true_npy_1)

# %%
print(df_pred.shape)
print(df_true.shape)
# Out:
# (12480, 1)
# (12480, 1)

# %%
# 1 day = 1440, 12h = 720, 6h= 360
i = 24*14 #len(df_pred)#1440*7
aa=[x for x in range(i)]
plt.figure(figsize=(25,10)) 

plt.plot(aa, df_true[-i:], marker='.', label="actual")
plt.plot(aa, df_pred[-i:], 'r', label="predicted")
plt.ylabel(df_pred.columns[0], size=15)
plt.xlabel('Time step (min)', size=15)
plt.title('1-steps (1 min) forecast', fontsize=14)
plt.legend(fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/range.py:1018, in RangeIndex.__getitem__(self, key)
#    1017 try:
# -> 1018     return self._range[new_key]
#    1019 except IndexError as err:
#
# IndexError: range object index out of range
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 8
#       6 l = 1
#       7 true_column = df_true[df_true.columns[0]]
# ----> 8 pred_column = df_pred[df_pred.columns[l]]
#      10 plt.plot(aa, true_column[-i:], marker='.', label="actual")
#      11 plt.plot(aa, pred_column[-i:], 'r', label="predicted")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/range.py:1020, in RangeIndex.__getitem__(self, key)
# ...

# %% [markdown]
# # 15 steps

# %%
pred_npy_15 =  np.load("./results/336_5_PatchTST_custom_ftMS_sl336_ll48_pl5_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/pred.npy") 
true_npy_15 =  np.load("./results/336_5_PatchTST_custom_ftMS_sl336_ll48_pl5_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/true.npy")

# %%
print(pred_npy_15.shape)
print(true_npy_15.shape)
# Out:
# (2496, 5, 1)
# (2496, 5, 1)

# %%
pred_npy_15 = pred_npy_15.reshape(2496, 5)
true_npy_15 = true_npy_15.reshape(2496, 5)

# Create DataFrame
df_pred = pd.DataFrame(pred_npy_15)
df_true = pd.DataFrame(true_npy_15)

# %%
# 1 day = 1440, 12h = 720, 6h= 360
i = 24*14#len(df_pred) #1440*7
aa=[x for x in range(i)]
plt.figure(figsize=(25,10)) 

l = 4
true_column = df_true[df_true.columns[0]]
pred_column = df_pred[df_pred.columns[l]]

plt.plot(aa, true_column[-i:], marker='.', label="actual")
plt.plot(aa, pred_column[-i:], 'r', label="predicted")
plt.ylabel(df_pred.columns[0], size=15)
plt.xlabel('Time step (min)', size=15)
plt.title('15-steps (15 min) forecast', fontsize=14)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# # 60 steps

# %%
pred_npy_60 =  np.load("./results/336_60_PatchTST_custom_ftMS_sl336_ll48_pl60_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/pred.npy") 
true_npy_60 =  np.load("./results/336_60_PatchTST_custom_ftMS_sl336_ll48_pl60_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/true.npy")

# %%
print(pred_npy_60.shape)
print(true_npy_60.shape)
# Out:
# (414976, 60, 1)
# (414976, 60, 1)

# %%
pred_npy_60 = pred_npy_60.reshape(414976, 60)
true_npy_60 = true_npy_60.reshape(414976, 60)

# Create DataFrame
df_pred = pd.DataFrame(pred_npy_60)
df_true = pd.DataFrame(true_npy_60)

# %%
# 1 day = 1440, 12h = 720, 6h= 360
i = len(df_pred) #1440*7
aa=[x for x in range(i)]
plt.figure(figsize=(25,10)) 

l = 59
true_column = df_true[df_true.columns[0]]
pred_column = df_pred[df_pred.columns[l]]

plt.plot(aa, true_column[-i:], marker='.', label="actual")
plt.plot(aa, pred_column[-i:], 'r', label="predicted")
plt.ylabel(df_pred.columns[0], size=15)
plt.xlabel('Time step (min)', size=15)
plt.title('60-steps (60 min) forecast', fontsize=14)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# # 96 steps

# %%
pred_npy_96 =  np.load("./results/336_96_PatchTST_custom_ftMS_sl336_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/pred.npy") 
true_npy_96 =  np.load("./results/336_96_PatchTST_custom_ftMS_sl336_ll48_pl96_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/true.npy")

# %%
print(pred_npy_96.shape)
print(true_npy_96.shape)
# Out:
# (414944, 96, 1)
# (414944, 96, 1)

# %%
pred_npy_96 = pred_npy_96.reshape(414944, 96)
true_npy_96 = true_npy_96.reshape(414944, 96)

# Create DataFrame
df_pred = pd.DataFrame(pred_npy_96)
df_true = pd.DataFrame(true_npy_96)

# %%
# 1 day = 1440, 12h = 720, 6h= 360
i = len(df_pred) #1440*7
aa=[x for x in range(i)]
plt.figure(figsize=(25,10)) 

l = 95
true_column = df_true[df_true.columns[0]]
pred_column = df_pred[df_pred.columns[l]]

plt.plot(aa, true_column[-i:], marker='.', label="actual")
plt.plot(aa, pred_column[-i:], 'r', label="predicted")
plt.ylabel(df_pred.columns[0], size=15)
plt.xlabel('Time step (min)', size=15)
plt.title('60-steps (60 min) forecast', fontsize=14)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# # 1440 input 15 horizon

# %%
pred_npy_1440 =  np.load("./results/1440_60_PatchTST_custom_ftMS_sl1440_ll48_pl60_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/pred.npy") 
true_npy_1440 =  np.load("./results/1440_60_PatchTST_custom_ftMS_sl1440_ll48_pl60_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/true.npy")

# %%
print(pred_npy_1440.shape)
print(true_npy_1440.shape)
# Out:
# (414976, 60, 1)
# (414976, 60, 1)

# %%
pred_npy_1440 = pred_npy_1440.reshape(414976, 60)
true_npy_1440 = true_npy_1440.reshape(414976, 60)

# Create DataFrame
df_pred = pd.DataFrame(pred_npy_1440)
df_true = pd.DataFrame(true_npy_1440)

# %%
# 1 day = 1440, 12h = 720, 6h= 360
i = 1440 #len(df_pred) #1440*7
aa=[x for x in range(i)]
plt.figure(figsize=(25,10)) 

l = 59
true_column = df_true[df_true.columns[0]]
pred_column = df_pred[df_pred.columns[l]]

plt.plot(aa, true_column[-i:], marker='.', label="actual")
plt.plot(aa, pred_column[-i:], 'r', label="predicted")
plt.ylabel(df_pred.columns[0], size=15)
plt.xlabel('Time step (min)', size=15)
plt.title('3-steps (3 min) forecast', fontsize=14)
plt.legend(fontsize=15)
plt.show()

# %%
# calculate MAE
mae_model = mean_absolute_error(true_column, pred_column)

# calculate MSE
mse_model = mean_squared_error(true_column, pred_column)

print('MAE, model predictions {:.3f}'.format(mae_model))
print('MSE, model predictions {:.3f}'.format(mse_model))
# Out:
# MAE, model predictions 0.167
# MSE, model predictions 0.096

# %% [markdown]
# # Real Pred ??

# %%
pred =  np.load("./results/336_15_PatchTST_custom_ftMS_sl336_ll48_pl15_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/pred.npy") 
real_pred =  np.load("./results/336_15_PatchTST_custom_ftMS_sl336_ll48_pl15_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/real_prediction.npy") 
true =  np.load("./results/336_15_PatchTST_custom_ftMS_sl336_ll48_pl15_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/true.npy")

# %%
print(pred.shape)
print(real_pred.shape)
print(true.shape)
# Out:
# (415008, 15, 1)
# (1, 15, 10)
# (415008, 15, 1)

# %%
pred = pred.reshape(415008, 15)
true_npy_1440 = true_npy_1440.reshape(415008, 15)

# Create DataFrame
df_pred = pd.DataFrame(pred_npy_1440)
df_true = pd.DataFrame(true_npy_1440)

# %%
# 1 day = 1440, 12h = 720, 6h= 360
i = len(df_pred) #1440*7
aa=[x for x in range(i)]
plt.figure(figsize=(25,10)) 

l = 2
true_column = df_true[df_true.columns[0]]
pred_column = df_pred[df_pred.columns[l]]

plt.plot(aa, true_column[-i:], marker='.', label="actual")
plt.plot(aa, pred_column[-i:], 'r', label="predicted")
plt.ylabel(df_pred.columns[0], size=15)
plt.xlabel('Time step (min)', size=15)
plt.title('3-steps (3 min) forecast', fontsize=14)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# # SCS DATA

# %%
pred =  np.load("./results/336_168_PatchTST_custom_ftMS_sl336_ll48_pl168_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/pred.npy") 
true =  np.load("./results/336_168_PatchTST_custom_ftMS_sl336_ll48_pl168_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/true.npy")

# %%
print(pred.shape)
print(true.shape)
# Out:
# (2336, 168, 1)
# (2336, 168, 1)

# %%
pred_npy = pred.reshape(2336, 168)
true_npy = true.reshape(2336, 168)

# Create DataFrame
df_pred = pd.DataFrame(pred_npy)
df_true = pd.DataFrame(true_npy)

# %%
# 1 day = 1440, 12h = 720, 6h= 360
i = 24*14 #len(df_pred) #1440*7
aa=[x for x in range(i)]
plt.figure(figsize=(25,10)) 

l = 167
true_column = df_true[df_true.columns[0]]
pred_column = df_pred[df_pred.columns[l]]

plt.plot(aa, true_column[-i:], marker='.', label="actual")
plt.plot(aa, pred_column[-i:], 'r', label="predicted")
plt.ylabel(df_pred.columns[0], size=15)
plt.xlabel('Time step (min)', size=15)
plt.title('60-steps (60 min) forecast', fontsize=14)
plt.legend(fontsize=15)
plt.show()

# %%
# 1 day = 1440, 12h = 720, 6h= 360
i = 24*7*2
h = 1
aa=[x for x in range(i)]
plt.figure(figsize=(25,10)) 

l = 167
true_column = df_true[df_true.columns[0]]
pred_column = df_pred[df_pred.columns[l]]

plt.plot(aa[:-h], true_column[-i:-h], marker='.', label="actual")
plt.plot(aa[:-h], pred_column[-i+h:], 'r', label="predicted")
plt.ylabel(df_pred.columns[0], size=15)
plt.xlabel('Time step (h)', size=15)
plt.title('3-steps (3 h) forecast', fontsize=14)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# # SLGT DATA

# %%
pred =  np.load("./results/336_48_PatchTST_custom_ftMS_sl336_ll48_pl48_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/pred.npy") 
true =  np.load("./results/336_48_PatchTST_custom_ftMS_sl336_ll48_pl48_dm128_nh16_el3_dl1_df256_fc1_ebtimeF_dtTrue_Exp_0/true.npy")

# %%
print(pred.shape)
print(true.shape)
# Out:
# (6944, 48, 1)
# (6944, 48, 1)

# %%
pred_npy = pred.reshape(6944, 48)
true_npy = true.reshape(6944, 48)

# Create DataFrame
df_pred = pd.DataFrame(pred_npy)
df_true = pd.DataFrame(true_npy)

# %%
# 1 day = 1440, 12h = 720, 6h= 360
i = len(df_true)#96*7*5
h = 4
aa=[x for x in range(i)]
plt.figure(figsize=(25,10)) 

l = 0
true_column = df_true[df_true.columns[0]]
pred_column = df_pred[df_pred.columns[l]]

plt.plot(aa[:-h], true_column[-i:-h], marker='.', label="actual")
plt.plot(aa[:-h], pred_column[-i+h:], 'r', label="predicted")
plt.ylabel(df_pred.columns[0], size=15)
plt.xlabel('Time step (h)', size=15)
plt.title('3-steps (3 h) forecast', fontsize=14)
plt.legend(fontsize=15)
plt.show()
